# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

chat = ChatGroq(
    model="openai/gpt-oss-20b",
    api_key=GROQ_API_KEY,
    temperature=0.3
)

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("resume/Mohit_Jadhav.pdf")

documents = loader.load()

context = "\n\n".join(
    doc.page_content
    for doc in documents
)
# Out:
# C:\Users\rajem\AppData\Local\Temp\ipykernel_12020\98606610.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

chat_history = []

system_message = SystemMessage(
    content=f"""
    You are a professional career coach and resume mentor.

    You help with:
    - Career Guidance
    - Resume Improvements
    - Interview Preparation
    - Job Search Strategy
    - Skill Gap Analysis

    Candidate Resume:
    {context}
    """
)

# %%
while True:
  user_input = input("You: ")

  if user_input.lower() in ['exit', 'quit']:
    print("\n Goodbye!!")

  # Add user message to memory
  chat_history.append(HumanMessage(content=user_input))

  #Build message list
  messages = [system_message] + chat_history

  print("\nCoach:", end = " ", flush=True)

  response_text = ""

  for chunk in chat.stream(messages):
    print(chunk.content, end="",flush=True)
    response_text = response_text + chunk.content


  #Add AI response to memory
  chat_history.append(AIMessage(content=response_text))

  print("\n")
# Out:
# You:  hii
# Hello! 👋
# I’m here to help you with anything from polishing your résumé and preparing for interviews to mapping out a job‑search strategy or identifying skill gaps.
#
# What would you like to focus on today?
# - Fine‑tuning your résumé?
# - Interview prep for data‑science roles?
# - Building a portfolio or project roadmap?
# - Exploring job opportunities in Bengaluru?
#
# Let me know, and we’ll dive right in!
# You:  Interview prep for data‑science roles?
# ## 🚀 Data‑Science Interview Prep Playbook
# *(Tailored for an entry‑level candidate like you, Mohit)*
#
# ---
#
# ### 1️⃣ Know the Interview Format
# | Stage | Typical Focus | What to Expect |
# |-------|---------------|----------------|
# | **Phone / Video Screening** | Basic fit, motivation, resume walk‑through | 30‑45 min, often a recruiter or hiring manager |
# | **Technical Phone / Video** | Core concepts, coding, SQL, ML fundamentals | 45‑60 min, may include a live coding challenge |
# | **On‑site / Virtual Deep Dive** | Project deep‑dive, case study, system design, behavioral | 2‑3 hrs, multiple interviewers (data scientist, engineer, manager) |
# | **Final/HR** | Culture fit, compensation, logistics | 15‑30 min |
#
# ---
#
# ### 2️⃣ Core Technical Topics to Master
#
# | Category | Key Topics | Sample Questions |
# |----------|------------|------------------|
# | **Python & Libraries** | Pandas, NumPy, Scikit‑learn, TensorFlow/Keras | *“Show me how you’d handle missing values in a DataFrame.”* |
# | **Statistics & Probability** | Descriptive stats, hypothesis testing, distributions | *“Explain the difference between a Type‑I and Type‑II error.”* |
# | **Machine Learning** | Supervised (regression, classification), unsupervised, model evaluation | *“How would you choose between a Random Forest and XGBoost?”* |
# | **Feature Engineering** | Encoding, scaling, interaction terms | *“Describe a time you engineered a feature that improved model performance.”* |
# | **SQL** | Joins, window functions, aggregation | *“Write a query to find the top 5 employees by sales in each region.”* |
# | **Model Deployment** | Flask, REST APIs, Docker, CI/CD basics | *“How would you expose a trained model as an API?”* |
# | **Generative AI / LLMs** | Prompt engineering, RAG, LangChain | *“Explain how you’d build a RAG pipeline for a knowledge base.”* |
# | **Computer Vision** | Transfer learning, CNNs, image preprocessing | *“Why use MobileNetV2 for mobile inference?”* |
# | **Evaluation & Bias** | Confusion matrix, ROC‑AUC, fairness metrics | *“How do you detect and mitigate bias in a model?”* |
#
# ---
#
# ### 3️⃣ Behavioral & Situational Questions
#
# | Situation | Prompt | How to Answer (STAR) |
# |-----------|--------|----------------------|
# | **Team Collaboration** | “Tell me about a time you worked with a non‑technical stakeholder.” | **S**: Project context<br>**T**: Your role<br>**A**: Actions (communication, demos)<br>**R**: Outcome (stakeholder buy‑in, project success) |
# | **Problem Solving** | “Describe a challenging data issue you resolved.” | **S**: Problem<br>**T**: Goal<br>**A**: Steps (EDA, debugging)<br>**R**: Result (accuracy improvement, time saved) |
# | **Learning** | “How do you keep up with new ML techniques?” | **S**: Need to learn<br>**T**: Specific skill<br>**A**: Resources (papers, courses)<br>**R**: Application (project or hackathon) |
# | **Failure** | “Share a project that didn’t go as planned.” | **S**: Project<br>**T**: Expectation<br>**A**: What you did<br>**R**: Lessons learned |
#
# ---
#
# ### 4️⃣ Project Deep‑Dive Prep
#
# Your résumé lists several impressive projects. Be ready to discuss each in depth:
#
# | Project | Key Talking Points |
# |---------|--------------------|
# | **SmartClaim AI** | • RAG pipeline architecture<br>• LangChain integration<br>• LLM choice (Groq) and prompt design<br>• Explainability & audit trail |
# | **Cancer Risk Prediction** | • Feature selection (clinical vs lifestyle)<br>• XGBoost hyper‑tuning<br>• Handling class imbalance<br>• Confidence scoring |
# | **Elephant Species Classification** | • Transfer learning strategy<br>• Data augmentation<br>• Deployment via Flask & Render<br>• Real‑time inference latency |
# | **Movie Recommendation System** | • Content‑based filtering logic<br>• TMDB API usage<br>• Flask API design<br>• Scaling considerations |
#
# **Tip:** Prepare a 2‑minute “pitch” for each project, then dive deeper into the technical stack when asked.
#
# ---
#
# ### 5️⃣ Mock Interview Flow (Sample)
#
# 1. **Resume Walk‑Through**
#    - Highlight your internship, projects, and hackathon achievements.
#    - Emphasize impact metrics (e.g., “improved forecasting accuracy by X%”).
#
# 2. **Technical Questions**
#    - *Python:* “Write a function to compute the median of a list.”
#    - *SQL:* “Find the average salary per department.”
#    - *ML:* “Explain bias‑variance trade‑off.”
#
# 3. **Case Study**
#    - *Scenario:* “Your company wants to predict churn for a SaaS product.”
#    - Walk through data understanding, feature engineering, model selection, evaluation, and deployment.
#
# 4. **Behavioral**
#    - Use STAR to answer collaboration, conflict, and learning questions.
#
# 5. **Ask Your Own Questions**
#    - Inquire about team structure, current ML stack, and growth opportunities.
#
# ---
#
# ### 6️⃣ Resources to Sharpen Skills
#
# | Resource | Focus | Why It Helps |
# |----------|-------|--------------|
# | **LeetCode (Python)** | Coding practice | Improves algorithmic thinking |
# | **Kaggle Competitions** | End‑to‑end ML | Builds portfolio & problem‑solving |
# | **DataCamp / Coursera** | SQL, ML fundamentals | Structured learning |
# | **FastAPI + Docker tutorials** | Deployment | Real‑world API skills |
# | **OpenAI Cookbook** | Prompt engineering | Hands‑on LLM practice |
# | **“Cracking the Data Science Interview” (Book)** | Interview prep | Sample questions & answers |
#
# ---
#
# ### 7️⃣ Final Checklist Before the Interview
#
# | ✅ | Item |
# |----|------|
# | ✅ | Update résumé with quantifiable results (e.g., “boosted model accuracy from 78% to 85%”). |
# | ✅ | Prepare a portfolio website or GitHub README that links to live demos. |
# | ✅ | Rehearse your 2‑minute project pitches. |
# | ✅ | Review company’s recent projects (LinkedIn, blogs) to tailor questions. |
# | ✅ | Test your video setup (camera, mic, lighting). |
# | ✅ | Have a list of 3‑5 questions ready for the interviewer. |
# | ✅ | Plan a 10‑minute break after the interview to decompress. |
#
# ---
#
# ### 🚀 Quick Practice Question
#
# > **“You have a dataset with 10,000 rows and 50 features. The target variable is binary. How would you approach building a baseline model and improving it?”**
#
# **Answer Outline:**
#
# 1. **Data Understanding** – EDA, missing values, class imbalance.
# 2. **Baseline** – Logistic Regression with simple preprocessing.
# 3. **Feature Engineering** – One‑hot encode categorical, scale numeric.
# 4. **Model Selection** – Try tree‑based models (Random Forest, XGBoost).
# 5. **Evaluation** – Use ROC‑AUC, precision‑recall, confusion matrix.
# 6. **Hyper‑parameter Tuning** – GridSearchCV or Optuna.
# 7. **Model Interpretation** – SHAP or feature importance.
# 8. **Deployment** – Wrap in Flask, expose `/predict` endpoint.
#
# Feel free to answer it aloud and I’ll give feedback!
#
# ---
#
# Let me know which area you’d like to drill deeper into—coding, case studies, or behavioral prep. Happy interviewing!
# You:  done
# Great! 🎉
# If you ever want to revisit any of the topics, dive into a new skill, or tackle another part of your career journey, just let me know. Good luck with your interviews—go knock them out of the park!
# You:  exit
#  Goodbye!!
#
# Alright! If you need anything else in the future, feel free to drop by. Good luck with everything, and have a great day!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 while True:
# ----> 2   user_input = input("You: ")
#       4   if user_input.lower() in ['exit', 'quit']:
#       5     print("\n Goodbye!!")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
