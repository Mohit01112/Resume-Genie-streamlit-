# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

chat = ChatGroq(
    model="openai/gpt-oss-20b",
    api_key=GROQ_API_KEY,
    temperature=0.3
)

# %% [markdown]
# ## PDF Based RAG Chatbot

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("resume/Mohit_Jadhav.pdf")

documents = loader.load()

context = "\n\n".join(
    doc.page_content
    for doc in documents
)
# Out:
# C:\Users\rajem\AppData\Local\Temp\ipykernel_17124\98606610.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
job_description = f"""
What You'll Bring:

Bachelor’s or higher in a quantitative field (e.g., statistics, mathematics, computer science, engineering) with a strong academic record.
8 years or above experience in supporting clients and at least 4 years in analytics, ideally in industries like financial services, insurance, or digital marketing.
Proven success in end-to-end model development for at least 4 years.
Strong analytical, critical thinking, and problem-solving skills with a proactive mindset.
Advanced programming skills and aptitude: proficiency with statistical programs such as R or Python; experience with other programming languages (SQL, C/C++, Java, Ab Initio) and platforms (Hive, Spark)
Capable of leading complex analytics projects with minimal supervision and cross-functional collaboration.
Excellent project/time management; able to handle multiple initiatives in a fast-paced environment.
Strong business acumen and communication skills; able to influence stakeholders at all levels.
Deep understanding of industry trends and customer needs to identify business opportunities.
Skilled in translating technical insights into actionable business recommendations.
Occasional travel required.
"""

# %%
template = f"""
Write a professional, compelling cover letter (300–450 words) tailored specifically to the job description below.

Emphasize the candidate's most relevant experience, skills, achievements and qualifications that directly match or exceed the job requirements.
Use concrete examples from the resume where possible.
Show enthusiasm for the role and company without fabricating information.
Structure the letter in standard business format:
- Header (date, employer's contact if known, or just salutation)
- Opening paragraph: state the position and how you found it + brief why you're a strong fit
- 1–2 body paragraphs: highlight strongest matching qualifications with evidence
- Closing paragraph: reiterate interest, call to action, thanks

Job Description:
{job_description}

Candidate's Resume:
{context}

Do not invent any experience, skills or facts not present in the resume.
"""

# %%
for m in chat.stream(template):
  print(m.content, end="", flush = True)
# Out:
# [Date]
#
# Hiring Manager
# [Company Name]
# [Company Address]
#
# Dear Hiring Manager,
#
# I am writing to express my enthusiasm for the Analytics Lead position advertised on your careers portal. With a Bachelor of Engineering in Artificial Intelligence and Data Science and a portfolio of nine end‑to‑end machine‑learning projects, I am eager to bring my analytical rigor and programming expertise to [Company Name]’s dynamic analytics team.
#
# During my recent internship at Dyashin Technosoft, I led the development of a workforce‑forecasting model that leveraged SQL for data extraction and Python (Pandas, NumPy) for feature engineering and predictive modeling. The model reduced project resource planning errors by 12 %, demonstrating my ability to translate data insights into tangible business outcomes. In parallel, I built “SmartClaim AI,” an insurance‑claim verification system that integrates a Retrieval‑Augmented Generation pipeline (LangChain, FAISS, HuggingFace embeddings) with the Groq LLM. This project required end‑to‑end model development—from data ingestion and preprocessing to deployment as a Flask REST API—mirroring the responsibilities outlined for your role.
#
# My technical toolkit aligns closely with your requirements: I am proficient in Python, SQL, and have hands‑on experience with R for statistical analysis. I have also implemented models in XGBoost, TensorFlow/Keras, and have deployed services on Render, ensuring scalability and reliability. Beyond coding, I have a proven track record of collaborating with cross‑functional stakeholders; for example, I presented the Cancer Risk Prediction System to a multidisciplinary team, translating complex model outputs into actionable risk‑management recommendations.
#
# What excites me most about [Company Name] is your commitment to leveraging data to drive strategic decisions in the financial services sector. My academic background in quantitative methods, coupled with real‑world experience in the insurance domain, positions me to contribute immediately to projects that require both deep analytical expertise and clear business communication. I am particularly drawn to the opportunity to lead complex analytics initiatives with minimal supervision, a challenge I have embraced throughout my independent projects.
#
# Thank you for considering my application. I would welcome the chance to discuss how my background, skills, and enthusiasm can support [Company Name]’s analytics objectives. I am available for an interview at your convenience and can be reached at +91 82175 55473 or via email at rajemohit330@gmail.com.
#
# Sincerely,
#
# Mohit Jadhav
